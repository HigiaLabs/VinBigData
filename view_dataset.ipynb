# %%
import pandas as pd
import numpy as np

# %%
dataset_train = 'train/train.csv'

# %%
dataset =  pd.read_csv(dataset_train)

# %%
no_finding =  dataset[dataset['class_name'] == 'No finding']

# %%
no_finding.to_csv('train/no_finding.csv')

# %%
finding =  dataset[dataset['class_name'] != 'No finding']

# %%
finding.to_csv('train/finding.csv')

# %%
dataset.head()
# Out:
#                            image_id          class_name  class_id rad_id  \
# 0  50a418190bc3fb1ef1633bf9678929b3          No finding        14    R11
# 1  21a10246a5ec7af151081d0cd6d65dc9          No finding        14     R7
# 2  9a5094b2563a1ef3ff50dc5c7ff71345        Cardiomegaly         3    R10
# 3  051132a778e61a86eb147c7c6f564dfe  Aortic enlargement         0    R10
# 4  063319de25ce7edb9b1c6b8881290140          No finding        14    R10
#
#     x_min   y_min   x_max   y_max
# 0     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN
# 2   691.0  1375.0  1653.0  1831.0
# 3  1264.0   743.0  1611.0  1019.0
# 4     NaN     NaN     NaN     NaN

# %%
#plot = dataset.plot.pie(y = 'class_id', subplots=True, figsize=(11, 6))

# %%
dataset.class_name.unique()
# Out:
# array(['No finding', 'Cardiomegaly', 'Aortic enlargement',
#        'Pleural thickening', 'ILD', 'Nodule/Mass', 'Pulmonary fibrosis',
#        'Lung Opacity', 'Atelectasis', 'Other lesion', 'Infiltration',
#        'Pleural effusion', 'Calcification', 'Consolidation',
#        'Pneumothorax'], dtype=object)

# %%
finding_groupby = finding.groupby('class_name').nunique()
finding_groupby
# Out:
#                     image_id  class_id  rad_id  x_min  y_min  x_max  y_max
# class_name
# Aortic enlargement      3067         1      10   1032    820   1010    959
# Atelectasis              186         1      10    253    252    260    257
# Calcification            452         1      11    750    707    778    715
# Cardiomegaly            2300         1      10    866   1059   1109   1149
# Consolidation            353         1       9    468    456    472    467
# ILD                      386         1      11    757    718    756    694
# Infiltration             613         1       9    879    834    912    884
# Lung Opacity            1322         1      10   1379   1314   1401   1341
# Nodule/Mass              826         1      10   1449   1350   1496   1385
# Other lesion            1134         1      10   1381   1363   1441   1430
# Pleural effusion        1032         1      10   1256   1455   1521   1170
# ...

# %%
finding_groupby.plot.pie(y = 'image_id', figsize=(20, 11))
# Out:
# <AxesSubplot:ylabel='image_id'>
